# %% [markdown]
# # Data Science Tools and Environments

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. SQL
# 3. Java
# 4. R

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. NumPy
# 2. Matplotlib
# 3. Scikit-learn
# 4. TensorFlow

# %% [markdown]
# |Data Science Tools|
# |---|
# |SAS|
# |Apache Madoop|
# |Apache Spark|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
#Common math problem
(3*5)+4
# Out:
# 19

# %%
#Hours into minutes equation
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# __Objectives__
# * List popular languages in DS
# * List popular libraries in DS
# * List popular tools in DS

# %% [markdown]
# ## Author
# Darrell Horton
